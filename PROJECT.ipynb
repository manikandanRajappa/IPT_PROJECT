# %% [markdown]
# #                                  WEATHER PREDICTION

# %%
import pandas as pd

# %%
weather = pd.read_csv("mani.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2023-05-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.51
# 2023-05-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  11.86
# 2023-05-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   9.40
# 2023-05-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  13.20
# 2023-05-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT13  WT14  WT15  WT16  WT17  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   1.0   NaN
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2023-05-18   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-05-19   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-05-20   NaN   NaN  1.65   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-05-21   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-05-22   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT18  WT19  WT21  WT22  WV01
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   1.0   NaN   NaN   NaN   NaN
# 1970-01-04   1.0   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2023-05-18   NaN   NaN   NaN   NaN   NaN
# 2023-05-19   NaN   NaN   NaN   NaN   NaN
# 2023-05-20   NaN   NaN   NaN   NaN   NaN
# 2023-05-21   NaN   NaN   NaN   NaN   NaN
# 2023-05-22   NaN   NaN   NaN   NaN   NaN
#
# [19500 rows x 45 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.506923
# ACSH       0.506872
# AWND       0.262359
# FMTM       0.480821
# PGTM       0.370821
# PRCP       0.000051
# SNOW       0.000154
# SNWD       0.000205
# TAVG       0.672974
# TMAX       0.000051
# TMIN       0.000051
# TSUN       0.998410
# WDF1       0.507128
# WDF2       0.493231
# WDF5       0.497487
# WDFG       0.737385
# WDFM       0.999949
# WESD       0.688667
# WSF1       0.506974
# WSF2       0.493231
# WSF5       0.497538
# WSFG       0.617282
# WSFM       0.999949
# WT01       0.629897
# WT02       0.934769
# WT03       0.933744
# WT04       0.982410
# WT05       0.981333
# WT06       0.990718
# WT07       0.994462
# WT08       0.798513
# WT09       0.992821
# WT11       0.999282
# WT13       0.887949
# WT14       0.954513
# WT15       0.997846
# WT16       0.662718
# WT17       0.996923
# WT18       0.940154
# WT19       0.999949
# WT21       0.999744
# WT22       0.997487
# WV01       0.999949
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-05-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1.65   0.0   0.0
# 2023-05-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN   NaN   NaN
#
#             tmax  tmin
# DATE
# 1970-01-01  28.0  22.0
# 1970-01-02  31.0  22.0
# 1970-01-03  38.0  25.0
# 1970-01-04  31.0  23.0
# 1970-01-05  35.0  21.0
# ...          ...   ...
# 2023-05-18  57.0  42.0
# 2023-05-19  66.0  51.0
# 2023-05-20  63.0  57.0
# 2023-05-21  72.0  56.0
# 2023-05-22   NaN   NaN
#
# [19500 rows x 7 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.apply(lambda x: (x == 9999).sum())
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16', '2023-05-17',
#        '2023-05-18', '2023-05-19', '2023-05-20', '2023-05-21', '2023-05-22'],
#       dtype='object', name='DATE', length=19500)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    142
# Name: DATE, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-05-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1.65   0.0   0.0
# 2023-05-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01  28.0  22.0    31.0
# 1970-01-02  31.0  22.0    38.0
# 1970-01-03  38.0  25.0    31.0
# 1970-01-04  31.0  23.0    35.0
# 1970-01-05  35.0  21.0    36.0
# ...          ...   ...     ...
# 2023-05-18  57.0  42.0    66.0
# 2023-05-19  66.0  51.0    63.0
# 2023-05-20  63.0  57.0    72.0
# 2023-05-21  72.0  56.0    72.0
# 2023-05-22  72.0  56.0     NaN
#
# [19500 rows x 8 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-05-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1.65   0.0   0.0
# 2023-05-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01  28.0  22.0    31.0
# 1970-01-02  31.0  22.0    38.0
# 1970-01-03  38.0  25.0    31.0
# 1970-01-04  31.0  23.0    35.0
# 1970-01-05  35.0  21.0    36.0
# ...          ...   ...     ...
# 2023-05-18  57.0  42.0    66.0
# 2023-05-19  66.0  51.0    63.0
# 2023-05-20  63.0  57.0    72.0
# 2023-05-21  72.0  56.0    72.0
# 2023-05-22  72.0  56.0    72.0
#
# [19500 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge

# %%
weather.corr()
# Out:
# C:\Users\Manikandan\AppData\Local\Temp\ipykernel_7224\2900882895.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   weather.corr()
#             prcp      snow      snwd      tmax      tmin    target
# prcp    1.000000  0.150573  0.001270 -0.007037  0.052802 -0.003085
# snow    0.150573  1.000000  0.232711 -0.174091 -0.158270 -0.171771
# snwd    0.001270  0.232711  1.000000 -0.258164 -0.255163 -0.239410
# tmax   -0.007037 -0.174091 -0.258164  1.000000  0.955118  0.914733
# tmin    0.052802 -0.158270 -0.255163  0.955118  1.000000  0.914865
# target -0.003085 -0.171771 -0.239410  0.914733  0.914865  1.000000

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-05-18    66.0   56.965792   9.034208
# 2023-05-19    63.0   65.644842   2.644842
# 2023-05-20    72.0   65.348102   6.651898
# 2023-05-21    72.0   70.914573   1.085427
# 2023-05-22    72.0   70.914573   1.085427
#
# [15850 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.1502040343885716

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2007-03-26    78.0   49.744725  28.255275
# 1999-01-02    53.0   25.911898  27.088102
# 1998-03-26    80.0   53.033957  26.966043
# 1985-04-18    84.0   57.071179  26.928821
# 1990-03-12    85.0   58.144310  26.855690
# ...            ...         ...        ...
# 2006-08-20    88.0   88.002937   0.002937
# 2019-03-01    40.0   40.002460   0.002460
# 1992-06-11    76.0   76.001641   0.001641
# 2011-09-16    66.0   66.000831   0.000831
# 2014-03-25    39.0   38.999920   0.000080
#
# [15850 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -1.242687
# snow   -0.409088
# snwd    0.052266
# tmax    0.448038
# tmin    0.516301
# dtype: float64

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-05-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1.65   0.0   0.0
# 2023-05-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-01  28.0  22.0    31.0             NaN                 NaN
# 1970-01-02  31.0  22.0    38.0             NaN                 NaN
# 1970-01-03  38.0  25.0    31.0       32.333333            0.175258
# 1970-01-04  31.0  23.0    35.0       33.333333           -0.070000
# 1970-01-05  35.0  21.0    36.0       34.666667            0.009615
# ...          ...   ...     ...             ...                 ...
# 2023-05-18  57.0  42.0    66.0       67.666667           -0.157635
# 2023-05-19  66.0  51.0    63.0       63.666667            0.036649
# 2023-05-20  63.0  57.0    72.0       62.000000            0.016129
# 2023-05-21  72.0  56.0    72.0       67.000000            0.074627
# 2023-05-22  72.0  56.0    72.0       69.000000            0.043478
#
#             rolling_3_tmin  rolling_3_tmin_pct  rolling_3_prcp  \
# DATE
# 1970-01-01             NaN                 NaN             NaN
# 1970-01-02             NaN                 NaN             NaN
# 1970-01-03       23.000000            0.086957        0.006667
# 1970-01-04       23.333333           -0.014286        0.006667
# 1970-01-05       23.000000           -0.086957        0.006667
# ...                    ...                 ...             ...
# 2023-05-18       49.000000           -0.142857        0.000000
# 2023-05-19       47.333333            0.077465        0.000000
# 2023-05-20       50.000000            0.140000        0.550000
# 2023-05-21       54.666667            0.024390        0.550000
# 2023-05-22       56.333333           -0.005917        0.550000
#
#             rolling_3_prcp_pct  rolling_14_tmax  rolling_14_tmax_pct  \
# DATE
# 1970-01-01                 NaN              NaN                  NaN
# 1970-01-02                 NaN              NaN                  NaN
# 1970-01-03                 2.0              NaN                  NaN
# 1970-01-04                -1.0              NaN                  NaN
# 1970-01-05                -1.0              NaN                  NaN
# ...                        ...              ...                  ...
# 2023-05-18                 NaN        71.071429            -0.197990
# 2023-05-19                 NaN        71.428571            -0.076000
# 2023-05-20                 2.0        70.785714            -0.109990
# 2023-05-21                -1.0        70.714286             0.018182
# 2023-05-22                -1.0        70.285714             0.024390
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-01              NaN                  NaN              NaN
# 1970-01-02              NaN                  NaN              NaN
# 1970-01-03              NaN                  NaN              NaN
# 1970-01-04              NaN                  NaN              NaN
# 1970-01-05              NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 2023-05-18        51.500000            -0.184466         0.000000
# 2023-05-19        52.000000            -0.019231         0.000000
# 2023-05-20        52.642857             0.082768         0.117857
# 2023-05-21        52.857143             0.059459         0.117857
# 2023-05-22        52.785714             0.060893         0.117857
#
#             rolling_14_prcp_pct
# DATE
# 1970-01-01                  NaN
# 1970-01-02                  NaN
# 1970-01-03                  NaN
# 1970-01-04                  NaN
# 1970-01-05                  NaN
# ...                         ...
# 2023-05-18                  NaN
# 2023-05-19                  NaN
# 2023-05-20                 13.0
# 2023-05-21                 -1.0
# 2023-05-22                 -1.0
#
# [19500 rows x 20 columns]

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax_pct', 'rolling_3_tmin', 'rolling_3_tmin_pct',
#        'rolling_3_prcp', 'rolling_3_prcp_pct', 'rolling_14_tmax',
#        'rolling_14_tmax_pct', 'rolling_14_tmin', 'rolling_14_tmin_pct',
#        'rolling_14_prcp', 'rolling_14_prcp_pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.802527655210253

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 37.7400694187981

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.369353  30.630647
# 2007-03-26    78.0   49.981156  28.018844
# 1998-03-26    80.0   52.009052  27.990948
# 2003-04-15    86.0   59.418323  26.581677
# 1985-04-18    84.0   58.463358  25.536642
# ...            ...         ...        ...
# 2001-12-02    53.0   53.002346   0.002346
# 1986-08-05    82.0   82.001182   0.001182
# 1985-08-03    80.0   79.999022   0.000978
# 1983-04-23    59.0   59.000813   0.000813
# 2014-01-25    36.0   35.999195   0.000805
#
# [15836 rows x 3 columns]

# %%
weather.loc["1990-03-07": "1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                ...
# 1990-03-07  32.0  14.0    39.0       33.666667           -0.049505  ...
# 1990-03-08  39.0  20.0    43.0       35.000000            0.114286  ...
# 1990-03-09  43.0  29.0    47.0       38.000000            0.131579  ...
# 1990-03-10  47.0  39.0    59.0       43.000000            0.093023  ...
# 1990-03-11  59.0  41.0    59.0       49.666667            0.187919  ...
# 1990-03-12  59.0  43.0    85.0       55.000000            0.072727  ...
# 1990-03-13  85.0  41.0    62.0       67.666667            0.256158  ...
# 1990-03-14  62.0  46.0    55.0       68.666667           -0.097087  ...
# 1990-03-15  55.0  43.0    62.0       67.333333           -0.183168  ...
# 1990-03-16  62.0  48.0    61.0       59.666667            0.039106  ...
# 1990-03-17  61.0  49.0    59.0       59.333333            0.028090  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1990-03-07        25.000000            -0.440000         0.047857
# 1990-03-08        24.071429            -0.169139         0.040714
# 1990-03-09        22.785714             0.272727         0.031429
# 1990-03-10        23.428571             0.664634         0.020714
# 1990-03-11        25.500000             0.607843         0.021429
# 1990-03-12        27.928571             0.539642         0.021429
# 1990-03-13        29.500000             0.389831         0.020000
# 1990-03-14        30.857143             0.490741         0.020000
# 1990-03-15        32.214286             0.334812         0.020000
# 1990-03-16        33.428571             0.435897         0.020000
# 1990-03-17        34.357143             0.426195         0.038571
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 1990-03-07            -1.000000       48.590112     45.428571       34.567783
# 1990-03-08            -1.000000       48.574841     46.571429       34.544586
# 1990-03-09            -0.681818       48.565978     45.619048       34.535771
# 1990-03-10            -0.517241       48.563492     43.809524       34.542857
# 1990-03-11             1.333333       48.580032     46.142857       34.553090
# 1990-03-12            -1.000000       48.596519     48.142857       34.566456
# 1990-03-13            -1.000000       48.654028     48.761905       34.576619
# 1990-03-14            -1.000000       48.675079     50.190476       34.594637
# 1990-03-15            -1.000000       48.685039     49.714286       34.607874
# 1990-03-16            -1.000000       48.705975     50.095238       34.628931
# 1990-03-17             5.740741       48.725275     48.095238       34.651491
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1990-03-07     31.857143        0.119410      0.111429
# 1990-03-08     31.190476        0.119220      0.076667
# 1990-03-09     30.952381        0.119046      0.036190
# 1990-03-10     31.761905        0.118873      0.071905
# 1990-03-11     31.904762        0.118764      0.126667
# 1990-03-12     34.285714        0.118576      0.167619
# 1990-03-13     34.285714        0.118389      0.091429
# 1990-03-14     36.809524        0.118202      0.259524
# 1990-03-15     35.761905        0.118016      0.066667
# 1990-03-16     35.619048        0.117830      0.083810
# 1990-03-17     34.619048        0.118053      0.079048
#
# [11 rows x 26 columns]

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <Axes: >

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    54.0   32.430619  21.569381
# 1980-01-14    51.0   44.600179   6.399821
# 1980-01-15    45.0   46.846655   1.846655
# 1980-01-16    40.0   42.211921   2.211921
# 1980-01-17    41.0   40.865606   0.134394
# ...            ...         ...        ...
# 2023-05-18    66.0   62.238927   3.761073
# 2023-05-19    63.0   68.945197   5.945197
# 2023-05-20    72.0   68.470775   3.529225
# 2023-05-21    72.0   70.706185   1.293815
# 2023-05-22    72.0   70.523603   1.476397
#
# [15836 rows x 3 columns]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-05-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1.65   0.0   0.0
# 2023-05-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                ...
# 1970-01-15  29.0  13.0    36.0       29.666667           -0.022472  ...
# 1970-01-16  36.0  21.0    43.0       30.333333            0.186813  ...
# 1970-01-17  43.0  30.0    42.0       36.000000            0.194444  ...
# 1970-01-18  42.0  25.0    25.0       40.333333            0.041322  ...
# 1970-01-19  25.0  16.0    24.0       36.666667           -0.318182  ...
# ...          ...   ...     ...             ...                 ...  ...
# 2023-05-18  57.0  42.0    66.0       67.666667           -0.157635  ...
# 2023-05-19  66.0  51.0    63.0       63.666667            0.036649  ...
# 2023-05-20  63.0  57.0    72.0       62.000000            0.016129  ...
# 2023-05-21  72.0  56.0    72.0       67.000000            0.074627  ...
# 2023-05-22  72.0  56.0    72.0       69.000000            0.043478  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-15        18.857143            -0.310606         0.022857
# 1970-01-16        18.785714             0.117871         0.022857
# 1970-01-17        19.142857             0.567164         0.022857
# 1970-01-18        19.285714             0.296296         0.030000
# 1970-01-19        18.928571            -0.154717         0.030000
# ...                     ...                  ...              ...
# 2023-05-18        51.500000            -0.184466         0.000000
# 2023-05-19        52.000000            -0.019231         0.000000
# 2023-05-20        52.642857             0.082768         0.117857
# 2023-05-21        52.857143             0.059459         0.117857
# 2023-05-22        52.785714             0.060893         0.117857
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 1970-01-15            -1.000000       29.733333     29.000000       19.066667
# 1970-01-16            -1.000000       30.125000     36.000000       19.187500
# 1970-01-17            -0.125000       30.882353     43.000000       19.823529
# 1970-01-18             2.333333       31.500000     42.000000       20.111111
# 1970-01-19            -1.000000       31.157895     25.000000       19.894737
# ...                         ...             ...           ...             ...
# 2023-05-18             0.000000       68.583986     68.296296       53.072246
# 2023-05-19             0.000000       68.582431     67.722222       53.070999
# 2023-05-20            13.000000       68.579074     69.129630       53.073361
# 2023-05-21            -1.000000       68.581130     70.092593       53.075120
# 2023-05-22            -1.000000       68.583183     71.092593       53.076877
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1970-01-15     13.000000        0.021333      0.000000
# 1970-01-16     21.000000        0.020000      0.000000
# 1970-01-17     30.000000        0.020000      0.020000
# 1970-01-18     25.000000        0.024444      0.100000
# 1970-01-19     16.000000        0.023158      0.000000
# ...                  ...             ...           ...
# 2023-05-18     53.222222        0.124810      0.117778
# 2023-05-19     53.055556        0.124735      0.216667
# 2023-05-20     53.388889        0.125652      0.102963
# 2023-05-21     53.555556        0.125577      0.105741
# 2023-05-22     54.777778        0.125502      0.127593
#
# [19486 rows x 26 columns]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-05-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1.65   0.0   0.0
# 2023-05-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-05-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                ...
# 1970-01-15  29.0  13.0    36.0       29.666667           -0.022472  ...
# 1970-01-16  36.0  21.0    43.0       30.333333            0.186813  ...
# 1970-01-17  43.0  30.0    42.0       36.000000            0.194444  ...
# 1970-01-18  42.0  25.0    25.0       40.333333            0.041322  ...
# 1970-01-19  25.0  16.0    24.0       36.666667           -0.318182  ...
# ...          ...   ...     ...             ...                 ...  ...
# 2023-05-18  57.0  42.0    66.0       67.666667           -0.157635  ...
# 2023-05-19  66.0  51.0    63.0       63.666667            0.036649  ...
# 2023-05-20  63.0  57.0    72.0       62.000000            0.016129  ...
# 2023-05-21  72.0  56.0    72.0       67.000000            0.074627  ...
# 2023-05-22  72.0  56.0    72.0       69.000000            0.043478  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-15        18.857143            -0.310606         0.022857
# 1970-01-16        18.785714             0.117871         0.022857
# 1970-01-17        19.142857             0.567164         0.022857
# 1970-01-18        19.285714             0.296296         0.030000
# 1970-01-19        18.928571            -0.154717         0.030000
# ...                     ...                  ...              ...
# 2023-05-18        51.500000            -0.184466         0.000000
# 2023-05-19        52.000000            -0.019231         0.000000
# 2023-05-20        52.642857             0.082768         0.117857
# 2023-05-21        52.857143             0.059459         0.117857
# 2023-05-22        52.785714             0.060893         0.117857
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 1970-01-15            -1.000000       29.733333     29.000000       19.066667
# 1970-01-16            -1.000000       30.125000     36.000000       19.187500
# 1970-01-17            -0.125000       30.882353     43.000000       19.823529
# 1970-01-18             2.333333       31.500000     42.000000       20.111111
# 1970-01-19            -1.000000       31.157895     25.000000       19.894737
# ...                         ...             ...           ...             ...
# 2023-05-18             0.000000       68.583986     68.296296       53.072246
# 2023-05-19             0.000000       68.582431     67.722222       53.070999
# 2023-05-20            13.000000       68.579074     69.129630       53.073361
# 2023-05-21            -1.000000       68.581130     70.092593       53.075120
# 2023-05-22            -1.000000       68.583183     71.092593       53.076877
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1970-01-15     13.000000        0.021333      0.000000
# 1970-01-16     21.000000        0.020000      0.000000
# 1970-01-17     30.000000        0.020000      0.020000
# 1970-01-18     25.000000        0.024444      0.100000
# 1970-01-19     16.000000        0.023158      0.000000
# ...                  ...             ...           ...
# 2023-05-18     53.222222        0.124810      0.117778
# 2023-05-19     53.055556        0.124735      0.216667
# 2023-05-20     53.388889        0.125652      0.102963
# 2023-05-21     53.555556        0.125577      0.105741
# 2023-05-22     54.777778        0.125502      0.127593
#
# [19486 rows x 26 columns]

# %%
weather.to_csv("C:\pmist\weather.csv")
